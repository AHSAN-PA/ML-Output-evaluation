# %% [markdown]
# ## For Model Evalutation ##

# %% [markdown]
# Replace the ytestdf in all the below lines with, your test output copy and paste, run the code. Save the output.

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, cohen_kappa_score


# Calculate metrics
accuracy = accuracy_score(ytestdf, yhatdf.round())
precision = precision_score(ytestdf, yhatdf.round())
recall = recall_score(ytestdf, yhatdf.round())
tn, fp, fn, tp = confusion_matrix(ytestdf, yhatdf.round()).ravel()
f1_class0 = f1_scoreytestdf, yhatdf.round(), pos_label=0)
f1_class1 = f1_score(ytestdf, yhatdf.round(), pos_label=1)
micro_avg_f1 = f1_score(ytestdf, yhatdf.round(), average='micro')
macro_avg_f1 = f1_score(ytestdf, yhatdf.round(), average='macro')
wtd_avg_f1 = f1_score(ytestdf, yhatdf.round(), average='weighted')
kappa = cohen_kappa_score(ytestdf, yhatdf.round())
npv = tn / (tn + fn)

# Create a DataFrame to hold the metrics
metrics_data = {
    'F3': [accuracy],
    'G3': [precision],
    'H3': [recall],
    'I3': [tn],
    'J3': [fp],
    'K3': [fn],
    'L3': [tp],
    'M3': [f1_class0],
    'N3': [f1_class1],
    'O3': [micro_avg_f1],
    'P3': [macro_avg_f1],
    'Q3': [wtd_avg_f1]
}

metrics_df = pd.DataFrame(metrics_data)

# Save the DataFrame to a CSV file with specified columns
metrics_df.to_csv('Model_Evaluaton.csv', index=False, header=False)

# Print confirmation
print('Model_Evaluaton.csv')

# %%
import pandas as pd

df=pd.read_csv('Model_Evaluaton.csv')



p=df['accuracy'].max()
q=df['precision'].min()
r=df['recall'].max()
s=df['tn'].min()
t=df['tn'].max()
u=df['fn'].min()
v=df['fn'].max()
w=df['fp'].min()
x=df['fp'].max()
y=df['tp'].min()
z=df['tp'].max()
a=df['f1_class0'].min()
b=df['f1_class0'].max()
c=df['f1_class1'].min()
d=df['f1_class1'].max()
f=df['micro_avg_f1'].min()
g=df['micro_avg_f1'].max()
h=df['macro_avg_f1'].min()
i=df['macro_avg_f1'].max()
j=df['wtd_avg_f1'].min()
k=df['wtd_avg_f1'].max()


print("print Necssary output")
